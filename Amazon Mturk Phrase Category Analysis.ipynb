# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Amazon_Mturk_Category_data.csv')

# %%
df=df[['Input.base_sentence', 'Input.phrase', 'Input.edited_sentence',
       'Answer.sentiment.label']]

# %%
df[0:100]
# Out:
#                                   Input.base_sentence  \
# 0   The presentation by the Queen at Buckingham Pa...
# 1   In patients with cases of bipolar disorder , t...
# 2   However , even though the Hollies ' master rig...
# 3   He was assassinated by the members of the Tura...
# 4   Some for - profit clinics exist , but they pro...
# ..                                                ...
# 95  At the end of the War he joined the Air Staff ...
# 96  After a particularly humiliating incident in t...
# 97  Bill Simmons , who at the time worked for ESPN...
# 98  Theatre in Santa Monica on November 5 , 2009 ,...
# 99  On April 16 , 2014 , Estrada was assigned to t...
#
#                                       Input.phrase  \
# 0                                      partner and
# 1                 that last for days or even weeks
# 2                                              new
# 3                            by Haidar Khan Turani
# 4                                             care
# ...

# %%
df.groupby(by=['Answer.sentiment.label']).count()
# Out:
#                                                     HITId  HITTypeId  Title  \
# Answer.sentiment.label
# Adding spammy, useless or derogatory content           82         82     82
# Copy Editing(Rephrase without changing meaning,...    231        231    231
# Elaboration(insert a fact or new meaningful ass...    481        481    481
# Other                                                  26         26     26
# Wikification ( formating style, adding or remov...     30         30     30
#
#                                                     Description  Keywords  \
# Answer.sentiment.label
# Adding spammy, useless or derogatory content                 82        82
# Copy Editing(Rephrase without changing meaning,...          231       231
# Elaboration(insert a fact or new meaningful ass...          481       481
# Other                                                        26        26
# Wikification ( formating style, adding or remov...           30        30
#
# ...
